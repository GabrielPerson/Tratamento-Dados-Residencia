# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load DataSet

# %%
df = pd.read_csv("SkillCraft1_Dataset.csv")

# %%
df.describe()
# Out:
#         Unnamed: 0        GameID  LeagueIndex          Age  HoursPerWeek  \
# count  3395.000000   3395.000000  3395.000000  3340.000000   3339.000000
# mean   1697.000000   4805.012371     4.184094    21.647904     15.910752
# std     980.196409   2719.944851     1.517327     4.206341     11.962912
# min       0.000000     52.000000     1.000000    16.000000      0.000000
# 25%     848.500000   2464.500000     3.000000    19.000000      8.000000
# 50%    1697.000000   4874.000000     4.000000    21.000000     12.000000
# 75%    2545.500000   7108.500000     5.000000    24.000000     20.000000
# max    3394.000000  10095.000000     8.000000    44.000000    168.000000
#
#            TotalHours          APM  SelectByHotkeys  AssignToHotkeys  \
# count     3338.000000  3395.000000      3395.000000      3395.000000
# mean       960.421809   117.046947         0.004299         0.000374
# std      17318.133922    51.945291         0.005284         0.000225
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  GameID  LeagueIndex   Age  HoursPerWeek  TotalHours       APM  \
# 0           0      52            5  27.0          10.0      3000.0  143.7180
# 1           1      55            5  23.0          10.0      5000.0  129.2322
# 2           2      56            4  30.0          10.0       200.0   69.9612
# 3           3      57            3  19.0          20.0       400.0  107.6016
# 4           4      58            3  32.0          10.0       500.0  122.8908
#
#    SelectByHotkeys  AssignToHotkeys  UniqueHotkeys          ...           \
# 0         0.003515         0.000220              7          ...
# 1         0.003304         0.000259              4          ...
# 2         0.001101         0.000336              4          ...
# 3         0.001034         0.000213              1          ...
# 4         0.001136         0.000327              2          ...
#
#    MinimapRightClicks  NumberOfPACs  GapBetweenPACs  ActionLatency  \
# ...

# %%
#df = pd.read_csv('titanic_data.csv')

# %% [markdown]
# ### FILL NA
#
# <p> -- Remove NA
# <p> -- Fill 0
# <p> -- Fill Media/Mediana, etc...

# %%
df_drop = df.dropna(axis=0)

# %%
df_drop.describe()
# Out:
#         Unnamed: 0       GameID  LeagueIndex          Age  HoursPerWeek  \
# count  3338.000000  3338.000000  3338.000000  3338.000000   3338.000000
# mean   1669.841522  4719.552127     4.120731    21.650389     15.909527
# std     964.336366  2656.919630     1.448170     4.206357     11.964495
# min       0.000000    52.000000     1.000000    16.000000      0.000000
# 25%     835.250000  2423.250000     3.000000    19.000000      8.000000
# 50%    1669.500000  4788.000000     4.000000    21.000000     12.000000
# 75%    2504.750000  6994.750000     5.000000    24.000000     20.000000
# max    3339.000000  9271.000000     7.000000    44.000000    168.000000
#
#            TotalHours          APM  SelectByHotkeys  AssignToHotkeys  \
# count     3338.000000  3338.000000      3338.000000      3338.000000
# mean       960.421809   114.575763         0.004023         0.000364
# std      17318.133922    48.111912         0.004726         0.000210
# ...

# %%
df['HoursPerWeek'].fillna(0,inplace=True)
df['Age'].fillna(0,inplace=True)
df['TotalHours'].fillna(0,inplace=True)

# %%
df.describe()
# Out:
#         Unnamed: 0        GameID  LeagueIndex          Age  HoursPerWeek  \
# count  3395.000000   3395.000000  3395.000000  3395.000000   3395.000000
# mean   1697.000000   4805.012371     4.184094    21.297202     15.648306
# std     980.196409   2719.944851     1.517327     4.987761     12.035697
# min       0.000000     52.000000     1.000000     0.000000      0.000000
# 25%     848.500000   2464.500000     3.000000    18.000000      8.000000
# 50%    1697.000000   4874.000000     4.000000    21.000000     12.000000
# 75%    2545.500000   7108.500000     5.000000    24.000000     20.000000
# max    3394.000000  10095.000000     8.000000    44.000000    168.000000
#
#            TotalHours          APM  SelectByHotkeys  AssignToHotkeys  \
# count     3395.000000  3395.000000      3395.000000      3395.000000
# mean       944.296907   117.046947         0.004299         0.000374
# std      17172.538309    51.945291         0.005284         0.000225
# ...

# %%
mean_HPW = df['HoursPerWeek'].mean()
mean_Age = df['Age'].mean()
mean_TH = df['TotalHours'].mean()

# %%
df.describe()
# Out:
#         Unnamed: 0        GameID  LeagueIndex          Age  HoursPerWeek  \
# count  3395.000000   3395.000000  3395.000000  3395.000000   3395.000000
# mean   1697.000000   4805.012371     4.184094    21.297202     15.648306
# std     980.196409   2719.944851     1.517327     4.987761     12.035697
# min       0.000000     52.000000     1.000000     0.000000      0.000000
# 25%     848.500000   2464.500000     3.000000    18.000000      8.000000
# 50%    1697.000000   4874.000000     4.000000    21.000000     12.000000
# 75%    2545.500000   7108.500000     5.000000    24.000000     20.000000
# max    3394.000000  10095.000000     8.000000    44.000000    168.000000
#
#            TotalHours          APM  SelectByHotkeys  AssignToHotkeys  \
# count     3395.000000  3395.000000      3395.000000      3395.000000
# mean       944.296907   117.046947         0.004299         0.000374
# std      17172.538309    51.945291         0.005284         0.000225
# ...

# %%
df['HoursPerWeek'].fillna(mean_HPW,inplace=True)
df['Age'].fillna(mean_Age,inplace=True)
df['TotalHours'].fillna(mean_TH,inplace=True)

# %%
df.describe()
